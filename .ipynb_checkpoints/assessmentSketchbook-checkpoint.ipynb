# %% [markdown]
# # materials for maths assessment

# %%
import pandas as pd
import numpy as np
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
# %matplotlib inline

# %%
# [Write your code in this cell]
# cereal_df = pd.read_csv("/tmp/tmp07wuam09/data/cereal.csv")
association_df = pd.read_csv('association.csv')

# %%
ax = sns.countplot(x="sex", data=association_df)

# ax.set(xlabel='common xlabel', ylabel='common ylabel')

# legend((line1, line2, line3), ('label1', 'label2', 'label3'))

# %%
# sns.distplot(association_df['height'])
sns.distplot(association_df['mass'])
plt.show()
# Out:
# /home/patrick/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(x="ethnicity", data=association_df)

# %%
# SUBPLOTS

x = np.arange(1,11,1)
x
x = np.linspace(1,10,11)
x

y1 = x
y2 = x*2
y3 = x**2
y = x**3

# %%
association_df.fillna(association_df.median(), inplace=True)

# %%
sns.distplot(association_df['metabolite_A'])
plt.show()
# Out:
# /home/patrick/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
association_df.hist(bins=25, figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f648ad02d30>,
# ...
#       dtype=object)

# %%
import numpy as np
from scipy import stats


## Define 2 random distributions
#Sample Size
N = 10
#Gaussian distributed data with mean = 2 and var = 1
a = np.random.randn(N) + 2
#Gaussian distributed data with with mean = 0 and var = 1
b = np.random.randn(N)

# %%
a
# Out:
# array([ 3.19321637,  2.27359013,  3.42929822,  1.51608062, -1.61112049,
#         1.662696  ,  2.07521929,  0.65163101,  2.23706137,  2.4878016 ])

# %%
b
# Out:
# array([ 0.9098634 , -1.50154218,  1.20108951, -1.42187293, -0.71374454,
#        -0.18870326, -1.84905778,  1.43341469, -0.60793198,  0.16579943])

# %%
## Calculate the Standard Deviation
#Calculate the variance to get the standard deviation

#For unbiased max likelihood estimate we have to divide the var by N-1, and therefore the parameter ddof = 1
var_a = a.var(ddof=1)
var_b = b.var(ddof=1)
var_b
# Out:
# 1.3667501214866866

# %%
b.var()
# Out:
# 1.230075109338018

# %%
#std deviation
s = np.sqrt((var_a + var_b)/2)
s
# Out:
# 1.3105084904232178

# %%
## Calculate the t-statistics
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))
t
# Out:
# 3.4958123726078285

# %%
stats.ttest_ind(a, b)
# Out:
# Ttest_indResult(statistic=3.4958123726078285, pvalue=0.00258060973682283)

# %%
SE = np.sqrt((var_a/10)+(var_b/10))
t_2 = a.mean()-b.mean()/SE
t_2
# Out:
# 2.2305144239140686

# %%
t
# Out:
# 3.4958123726078285

# %%
# stats.ttest_ind(rvs1, rvs3)
